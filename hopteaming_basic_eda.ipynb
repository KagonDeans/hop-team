# %%
#Load data into sqlite database
import numpy as np
import pandas as pd
import sqlite3

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Define a few functions

# %%
db = sqlite3.connect('./data/npidata_final.sqlite')

query = "SELECT * FROM nppes LIMIT 5"

hopteaming = pd.read_sql(query, db)

db.close()

# %%
hopteaming.head()
# Out:
#           NPI  Entity_Type_Code  \
# 0  1679576722               1.0
# 1  1588667638               1.0
# 2  1497758544               2.0
# 3  1306849450               NaN
# 4  1215930367               1.0
#
#   Provider Organization Name (Legal Business Name)  \
# 0                                             None
# 1                                             None
# 2           CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                             None
# 4                                             None
#
#   Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                           WIEBE               DAVID                    A
# 1                         PILCHER             WILLIAM                    C
# 2                            None                None                 None
# 3                            None                None                 None
# 4                         GRESSOT             LAURENT                 None
#
#   Provider Name Prefix Text Provider Name Suffix Text  \
# 0                      None                      None
# 1                       DR.                      None
# 2                      None                      None
# 3                      None                      None
# 4                       DR.                      None
#
#   Provider Credential Text  \
# 0                     M.D.
# 1                       MD
# 2                     None
# 3                     None
# 4                     M.D.
#
#   Provider First Line Business Practice Location Address  \
# 0                                   3500 CENTRAL AVE
# 1                                   1824 KING STREET
# 2                                    3418 VILLAGE DR
# 3                                               None
# 4                                   17323 RED OAK DR
#
#   Provider Second Line Business Practice Location Address  \
# 0                                               None
# 1                                          SUITE 300
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Provider Business Practice Location Address City Name  \
# 0                                            KEARNEY
# 1                                       JACKSONVILLE
# 2                                       FAYETTEVILLE
# 3                                               None
# 4                                            HOUSTON
#
#   Provider Business Practice Location Address State Name  \
# 0                                                 NE
# 1                                                 FL
# 2                                                 NC
# 3                                               None
# 4                                                 TX
#
#    Provider Business Practice Location Address Postal Code  \
# 0                                        688472944.0
# 1                                        322044736.0
# 2                                        283044552.0
# 3                                                NaN
# 4                                        770901243.0
#
#   Healthcare Provider Taxonomy Code_1  \
# 0                          207X00000X
# 1                          207RC0000X
# 2                          251G00000X
# 3                                None
# 4                          174400000X
#
#   Healthcare Provider Primary Taxonomy Switch_1  \
# 0                                             Y
# 1                                             Y
# 2                                             Y
# 3                                          None
# 4                                             N
#
#   Healthcare Provider Taxonomy Code_2  \
# 0                                None
# 1                          207RC0000X
# 2                                None
# 3                                None
# 4                          207RH0003X
#
#   Healthcare Provider Primary Taxonomy Switch_2  \
# 0                                          None
# 1                                             N
# 2                                          None
# 3                                          None
# 4                                             Y
#
#   Healthcare Provider Taxonomy Code_3  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_3  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_4  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_4  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_5  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_5  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_6  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_6  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_7  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_7  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_8  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_8  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_9  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
#
#   Healthcare Provider Primary Taxonomy Switch_9  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   Healthcare Provider Taxonomy Code_10  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   Healthcare Provider Primary Taxonomy Switch_10  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   Healthcare Provider Taxonomy Code_11  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   Healthcare Provider Primary Taxonomy Switch_11  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   Healthcare Provider Taxonomy Code_12  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   Healthcare Provider Primary Taxonomy Switch_12  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   Healthcare Provider Taxonomy Code_13  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   Healthcare Provider Primary Taxonomy Switch_13  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   Healthcare Provider Taxonomy Code_14  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   Healthcare Provider Primary Taxonomy Switch_14  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#   Healthcare Provider Taxonomy Code_15  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
#
#   Healthcare Provider Primary Taxonomy Switch_15 Taxonomy_Code  \
# 0                                           None    207X00000X
# 1                                           None    207RC0000X
# 2                                           None    251G00000X
# 3                                           None          None
# 4                                           None    207RH0003X
#
#                   Classification zipcodes   CBSA
# 0            Orthopaedic Surgery    68847  28260
# 1              Internal Medicine    32204  27260
# 2  Hospice Care, Community Based    28304  22180
# 3                           None    00000      0
# 4              Internal Medicine    77090  26420

# %%
hopteaming.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 48 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   NPI                                                      5 non-null      int64
#  1   Entity_Type_Code                                         4 non-null      float64
#  2   Provider Organization Name (Legal Business Name)         1 non-null      object
#  3   Provider Last Name (Legal Name)                          3 non-null      object
#  4   Provider First Name                                      3 non-null      object
#  5   Provider Middle Name                                     2 non-null      object
#  6   Provider Name Prefix Text                                2 non-null      object
#  7   Provider Name Suffix Text                                0 non-null      object
#  8   Provider Credential Text                                 3 non-null      object
#  9   Provider First Line Business Practice Location Address   4 non-null      object
#  10  Provider Second Line Business Practice Location Address  1 non-null      object
#  11  Provider Business Practice Location Address City Name    4 non-null      object
#  12  Provider Business Practice Location Address State Name   4 non-null      object
#  13  Provider Business Practice Location Address Postal Code  4 non-null      float64
#  14  Healthcare Provider Taxonomy Code_1                      4 non-null      object
#  15  Healthcare Provider Primary Taxonomy Switch_1            4 non-null      object
#  16  Healthcare Provider Taxonomy Code_2                      2 non-null      object
#  17  Healthcare Provider Primary Taxonomy Switch_2            2 non-null      object
#  18  Healthcare Provider Taxonomy Code_3                      0 non-null      object
#  19  Healthcare Provider Primary Taxonomy Switch_3            0 non-null      object
#  20  Healthcare Provider Taxonomy Code_4                      0 non-null      object
#  21  Healthcare Provider Primary Taxonomy Switch_4            0 non-null      object
#  22  Healthcare Provider Taxonomy Code_5                      0 non-null      object
#  23  Healthcare Provider Primary Taxonomy Switch_5            0 non-null      object
#  24  Healthcare Provider Taxonomy Code_6                      0 non-null      object
#  25  Healthcare Provider Primary Taxonomy Switch_6            0 non-null      object
#  26  Healthcare Provider Taxonomy Code_7                      0 non-null      object
#  27  Healthcare Provider Primary Taxonomy Switch_7            0 non-null      object
#  28  Healthcare Provider Taxonomy Code_8                      0 non-null      object
#  29  Healthcare Provider Primary Taxonomy Switch_8            0 non-null      object
#  30  Healthcare Provider Taxonomy Code_9                      0 non-null      object
#  31  Healthcare Provider Primary Taxonomy Switch_9            0 non-null      object
#  32  Healthcare Provider Taxonomy Code_10                     0 non-null      object
#  33  Healthcare Provider Primary Taxonomy Switch_10           0 non-null      object
#  34  Healthcare Provider Taxonomy Code_11                     0 non-null      object
#  35  Healthcare Provider Primary Taxonomy Switch_11           0 non-null      object
#  36  Healthcare Provider Taxonomy Code_12                     0 non-null      object
#  37  Healthcare Provider Primary Taxonomy Switch_12           0 non-null      object
#  38  Healthcare Provider Taxonomy Code_13                     0 non-null      object
#  39  Healthcare Provider Primary Taxonomy Switch_13           0 non-null      object
#  40  Healthcare Provider Taxonomy Code_14                     0 non-null      object
#  41  Healthcare Provider Primary Taxonomy Switch_14           0 non-null      object
#  42  Healthcare Provider Taxonomy Code_15                     0 non-null      object
#  43  Healthcare Provider Primary Taxonomy Switch_15           0 non-null      object
#  44  Taxonomy_Code                                            4 non-null      object
#  45  Classification                                           4 non-null      object
#  46  zipcodes                                                 5 non-null      object
#  47  CBSA                                                     5 non-null      int64
# dtypes: float64(2), int64(2), object(44)
# memory usage: 2.0+ KB

# %%
db = sqlite3.connect('./data/npidata_final.sqlite')

query = "SELECT * FROM npi LIMIT 5"

npi = pd.read_sql(query, db)

db.close()

# %%
npi.head()
# Out:
#      from_npi      to_npi  patient_count  transaction_count  average_day_wait  \
# 0  1508085911  1730166125             58                 67            23.925
# 1  1508167040  1730166125             51                 51            28.196
# 2  1508863549  1730166125            340                391            18.302
# 3  1508867870  1730166125             50                 79            12.658
# 4  1508011040  1730166224            132                145             8.579
#
#    std_day_wait
# 0        43.923
# 1        52.876
# 2        42.422
# 3        26.402
# 4        28.053

# %%
npi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   from_npi           5 non-null      int64
#  1   to_npi             5 non-null      int64
#  2   patient_count      5 non-null      int64
#  3   transaction_count  5 non-null      int64
#  4   average_day_wait   5 non-null      float64
#  5   std_day_wait       5 non-null      float64
# dtypes: float64(2), int64(4)
# memory usage: 372.0 bytes

# %%
db = sqlite3.connect('./data/npidata_final.sqlite')

query = 'SELECT "Provider First Line Business Practice Location Address" FROM nppes'

rename_test = pd.read_sql(query, db)

db.close()

# %%
rename_test.head()
# Out:
#   Provider First Line Business Practice Location Address
# 0                                   3500 CENTRAL AVE
# 1                                   1824 KING STREET
# 2                                    3418 VILLAGE DR
# 3                                               None
# 4                                   17323 RED OAK DR

# %% [markdown]
# First, build a profile of providers referring patients to the major hospitals in Nashville.
#
# Are certain specialties more likely to refer to a particular hospital over the others?

# %%
#First select out all practices in Nashville
#Then select out important information from npi's
#Then join them together
#Next, what are the major Nashville Hospitals?
    #Vanderbilt
    #Centennial
    #St. Thomas (midtown, west)
    #Nashville General
    #VA

# %%
db = sqlite3.connect('./data/npidata_final.sqlite')

query = 'SELECT "Provider Organization Name (Legal Business Name)", "Provider Business Practice Location Address City Name", "NPI", "Classification", "Taxonomy_Code" FROM nppes WHERE "Provider Business Practice Location Address City Name" LIKE "%NASHVILLE%"'

Nashville_Practices = pd.read_sql(query, db)

db.close()

# %%
Nashville_Practices
# Out:
#       Provider Organization Name (Legal Business Name)  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ...                                                ...
# 50385                                             None
# 50386                                             None
# 50387                                             None
# 50388                                             None
# 50389                                             None
#
#       Provider Business Practice Location Address City Name         NPI  \
# 0                                              NASHVILLE     1134122187
# 1                                              NASHVILLE     1003819046
# 2                                              NASHVILLE     1922001957
# 3                                              NASHVILLE     1760485817
# 4                                              NASHVILLE     1437152485
# ...                                                  ...            ...
# 50385                                          NASHVILLE     1902660038
# 50386                                          NASHVILLE     1669236709
# 50387                                          NASHVILLE     1972367977
# 50388                                          NASHVILLE     1205690252
# 50389                                          NASHVILLE     1205690179
#
#                 Classification Taxonomy_Code
# 0           Nurse Practitioner    363L00000X
# 1      Obstetrics & Gynecology    207VG0400X
# 2      Obstetrics & Gynecology    207V00000X
# 3      Obstetrics & Gynecology    207V00000X
# 4      Obstetrics & Gynecology    207V00000X
# ...                        ...           ...
# 50385            Social Worker    104100000X
# 50386      Physician Assistant    363A00000X
# 50387       Nurse Practitioner    363LA2100X
# 50388               Pharmacist    1835P0018X
# 50389            Social Worker    1041C0700X
#
# [50390 rows x 5 columns]

# %%
db = sqlite3.connect('./data/npidata_final.sqlite')

query = 'SELECT "from_npi", "to_npi", "patient_count" FROM npi'

npis_patient_count = pd.read_sql(query, db)

db.close()
